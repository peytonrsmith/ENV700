# %% [markdown]
# # Jupyter Notebooks in VS Code: code, notes, kernels, and workflow
#
# **ENV 700 — Environmental Data Exploration with Python**
#
# In this notebook you will practice using a Jupyter Notebook as a working document: part code file, part lab notebook, part reproducible record of your analysis.
#
# By the end, you should be able to:
#
# - Explain what a notebook cell is and why notebooks are useful for exploratory analysis.
# - Write simple Markdown notes without memorizing a large formatting reference.
# - Run Python code cells and understand that variables persist in the active kernel session.
# - Describe what the Python kernel is and why selecting the correct kernel matters.
# - Use a few VS Code notebook tools that support an efficient coding workflow.

# %% [markdown]
# ## 1. What is a Jupyter Notebook?
#
# A Jupyter Notebook is an interactive document made of **cells**. The two cell types we will use most are:
#
# - **Markdown cells** for explanations, headings, links, lists, formulas, and interpretation.
# - **Code cells** for Python commands that can be executed.
#
# For environmental data analysis, notebooks are useful because they let you keep code, outputs, figures, and interpretation close together. That makes your work easier to inspect, revise, and share.
#
# > A useful mental model: a notebook is a transparent analysis trail, not just a place to run code.

# %% [markdown]
# ## 2. Markdown: enough to write useful notes
#
# You do **not** need to memorize Markdown. For now, focus on the few patterns that make your notebooks readable.
#
# ### Common Markdown patterns
#
# ```markdown
# # Large heading
# ## Section heading
# ### Smaller heading
#
# Plain text paragraph.
#
# - Bullet item
# - Another bullet item
#
# 1. Numbered step
# 2. Next numbered step
#
# **bold text**
# *italic text*
# `inline code`
#
# [link text](https://example.com)
# ```
#
# ### Your turn
#
# Double-click this cell, then add one sentence below describing why notebooks might be useful in a data analysis course.
#
# **My sentence:**
#
# They allow you to show how to got answers and why they matter in one place.

# %% [markdown]
# ## 3. Markdown as a lab notebook
#
# Good analysis notebooks usually include short written notes before and after code. The goal is not fancy formatting. The goal is to make your thinking visible.
#
# Try using this pattern throughout the course:
#
# 1. **Purpose** — What question or task is this section addressing?
# 2. **Code** — What commands did you run?
# 3. **Output** — What happened?
# 4. **Interpretation** — What does the output mean?
# 5. **Next step** — What will you try next?
#
# ### Practice prompt
#
# Create a new Markdown cell below this one and write a two-sentence note answering:
#
# - What kind of environmental dataset would you like to explore this semester?
# - What is one question you might ask of that dataset?

# %% [markdown]
# I want to explore geospatial datasets. One I want to explore in particular is a dataset on prescribed burns in 2025 on federal lands and see if government policies around this time significantly reduced the amount of prescribed burns that would normally occur.

# %% [markdown]
# ## 4. Running Python code cells
#
# A code cell contains Python code. To run a cell in VS Code, use the run button beside the cell or press **Shift + Enter**.
#
# Run the next cell. You do not need to understand every part of the Python syntax yet. Focus on the workflow: run a cell, inspect the output, and revise if needed.

# %%
print("Hello from a Jupyter Notebook in VS Code!")
# Out:
# Hello from a Jupyter Notebook in VS Code!

# %% [markdown]
# Python can also act like a calculator.

# %%
# Estimated annual precipitation total from monthly values, in millimeters
monthly_precip_mm = [82, 74, 91, 105, 118, 96, 88, 84, 93, 109, 101, 87]
annual_precip_mm = sum(monthly_precip_mm)
annual_precip_mm
# Out:
# 1128

# %% [markdown]
# ## 5. Variables persist in the kernel
#
# When you run a code cell, Python stores objects such as numbers, text, lists, and tables in memory. These stored objects are called **variables**.
#
# The important notebook workflow idea is this:
#
# > Code cells are separate on the page, but they share the same active Python session while the kernel is running.
#
# Run the next cell. It uses the variable `annual_precip_mm`, which was created in the previous code cell.

# %%
annual_precip_inches = annual_precip_mm / 25.4
annual_precip_inches
# Out:
# 44.40944881889764

# %% [markdown]
# ### Kernel-state caution
#
# Because notebooks remember variables, code may work only because you ran an earlier cell. This is useful, but it can also make notebooks confusing.
#
# Good habit: when you think a notebook is finished, use **Restart Kernel and Run All Cells** to check that it runs correctly from top to bottom.

# %% [markdown]
# ## 6. What is the Python kernel?
#
# The **kernel** is the running Python process that executes your code. Your notebook is the document; the kernel is the engine doing the computation.
#
# The kernel determines:
#
# - Which Python installation runs your code.
# - Which packages are available to import.
# - Which variables currently exist in memory.
# - Whether previous cell outputs reflect the current session.
#
# In this course, you should usually select the kernel associated with your **Miniforge/conda course environment**.
#
# ### Check your active Python
#
# Run the next cell and inspect the output. The path should point to the Python environment you intend to use for this course.

# %%
import sys

print("Python executable:")
print(sys.executable)

print("Python version:")
print(sys.version)
# Out:
# Python executable:
# /home/codespace/.python/current/bin/python
# Python version:
# 3.12.1 (main, Mar 11 2026, 12:17:56) [GCC 13.3.0]

# %% [markdown]
# ### Kernel workflow checklist
#
# Use this checklist when something seems wrong:
#
# - Did I select the correct kernel in the upper-right corner of the notebook?
# - Did I install the needed package into this same environment?
# - Did I restart the kernel after changing environments or installing packages?
# - Did I run the notebook cells in order from top to bottom?

# %% [markdown]
# ## 7. Importing packages without making this a coding lesson
#
# A package is reusable code written by someone else. Later we will use packages for tables, spatial data, statistics, and visualization.
#
# For now, just notice the pattern:
#
# ```python
# import package_name
# ```
#
# Run the next cell. It imports `math`, a standard Python package, and uses it to compute a square root.

# %%
import math

math.sqrt(144)
# Out:
# 12.0

# %% [markdown]
# ## 8. A tiny environmental data example
#
# The next few cells create and inspect a small dataset. Do not worry about memorizing the code yet. Focus on how notebooks support incremental exploration.

# %%
# A small dataset represented with built-in Python objects
sites = ["Pine Creek", "Maple Wetland", "Cedar Marsh", "Oak Ridge"]
ph = [6.8, 7.2, 6.5, 5.9]
dissolved_oxygen_mg_l = [8.1, 7.4, 6.8, 9.0]

sites
# Out:
# ['Pine Creek', 'Maple Wetland', 'Cedar Marsh', 'Oak Ridge']

# %%
# Pair each site with its pH value
for site, value in zip(sites, ph):
    print(site, "pH =", value)
# Out:
# Pine Creek pH = 6.8
# Maple Wetland pH = 7.2
# Cedar Marsh pH = 6.5
# Oak Ridge pH = 5.9

# %% [markdown]
# ### Add interpretation
#
# Create a Markdown cell below this one. In one or two sentences, describe which site has the lowest pH and what you might want to investigate next.

# %% [markdown]
# Oak Ridge has the lowest pH and would want to investigate how dissolved oxygen amounts impact this.

# %% [markdown]
# ## 9. First look at a table with pandas
#
# `pandas` is a major Python package for tabular data. We will use it often later. For now, just observe that a notebook can display tables directly below code cells.

# %%
import pandas as pd

data = pd.DataFrame({
    "site": sites,
    "pH": ph,
    "dissolved_oxygen_mg_l": dissolved_oxygen_mg_l,
})

data
# Out:
#             site   pH  dissolved_oxygen_mg_l
# 0     Pine Creek  6.8                    8.1
# 1  Maple Wetland  7.2                    7.4
# 2    Cedar Marsh  6.5                    6.8
# 3      Oak Ridge  5.9                    9.0

# %%
data.describe()
# Out:
#              pH  dissolved_oxygen_mg_l
# count  4.000000               4.000000
# mean   6.600000               7.825000
# std    0.547723               0.946485
# min    5.900000               6.800000
# 25%    6.350000               7.250000
# 50%    6.650000               7.750000
# 75%    6.900000               8.325000
# max    7.200000               9.000000

# %% [markdown]
# ## 10. First plot
#
# Notebooks are especially useful when you are exploring data visually. Run the next cell to create a simple plot.

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.bar(data["site"], data["pH"])
plt.axhline(7.0, linestyle="--")
plt.ylabel("pH")
plt.title("pH by monitoring site")
plt.xticks(rotation=30, ha="right")
plt.show()

# %% [markdown]
# ### Interpretation checkpoint
#
# Add a Markdown cell below this one and answer:
#
# - Which site appears most acidic?
# - What additional context would you need before making an environmental conclusion?

# %% [markdown]
# Oak Ridge seems most acidic. Would need information on if any pesticides or fertilizers have recently been applied to these areas as well as ground cover.

# %% [markdown]
# ## 11. VS Code features that help with notebooks
#
# VS Code adds several workflow tools around notebooks. You do not need to master them today, but you should know they exist.
#
# ### Features to notice during this lesson
#
# - **Kernel picker**: choose the Python environment that runs the notebook.
# - **Variable view / variable explorer**: inspect objects currently stored in the kernel.
# - **Data Viewer**: open table-like variables for filtering and inspection.
# - **Autocomplete / IntelliSense**: get suggestions while writing code.
# - **Linting**: get warnings about possible code problems.
# - **Formatting**: make code more readable without changing what it does.
# - **Debugging**: step through code when simple output inspection is not enough.
# - **Outline / headings**: use Markdown headings to navigate longer notebooks.
# - **Run All / Restart / Clear Outputs**: manage reproducibility and notebook state.
# - **Version control with Git**: save meaningful milestones as your notebook evolves.
#
# ### In-class VS Code scavenger hunt
#
# After running several cells, try to find:
#
# 1. The current kernel name.
# 2. A list of active variables.
# 3. The variable named `data` in a table viewer.
# 4. The command to restart the kernel.
# 5. The command to run all cells.

# %% [markdown]
# ## 12. Debugging mindset: slow down the code
#
# Debugging means inspecting code while it runs. In VS Code notebooks, you can debug cells when you need more than printed output.
#
# For today, use a simpler habit first: add small print statements and inspect intermediate results.

# %%
# Intentional workflow example: inspect intermediate values
mean_ph = sum(ph) / len(ph)
print("Number of pH values:", len(ph))
print("Mean pH:", mean_ph)

for site, value in zip(sites, ph):
    difference = value - mean_ph
    print(site, "difference from mean pH:", round(difference, 2))
# Out:
# Number of pH values: 4
# Mean pH: 6.6
# Pine Creek difference from mean pH: 0.2
# Maple Wetland difference from mean pH: 0.6
# Cedar Marsh difference from mean pH: -0.1
# Oak Ridge difference from mean pH: -0.7

# %% [markdown]
# ## 13. Common notebook problems and fixes
#
# | Symptom | Likely cause | First thing to try |
# |---|---|---|
# | `NameError` | A variable has not been created in this kernel session | Run earlier cells or restart and run all |
# | `ModuleNotFoundError` | The package is not installed in the selected environment | Check the kernel and install into that environment |
# | Output seems outdated | The code changed but the cell was not re-run | Re-run the cell |
# | Notebook works for me but not someone else | Hidden state, missing data, or different environment | Restart and run all; check paths and environment |
# | Git diff is noisy | Notebook outputs changed | Clear outputs before committing when appropriate |

# %% [markdown]
# ## 14. Notebook habits for this course
#
# Use these habits from the start:
#
# - Open the whole project folder in VS Code, not just a single file.
# - Select the intended Miniforge/conda kernel before running cells.
# - Use Markdown headings to structure the notebook.
# - Write short purpose and interpretation notes around code.
# - Run cells from top to bottom when checking your work.
# - Keep raw data unchanged; write outputs to an organized project folder.
# - Commit meaningful changes with Git.
# - Avoid treating notebooks as scratchpads only; make them readable enough for your future self.

# %% [markdown]
# ## 15. Exit ticket
#
# Create a Markdown cell below and answer these questions:
#
# 1. What is one advantage of using a Jupyter Notebook for exploratory data analysis?
# Can write structured explainations of what did and why as well as results. Makes everything much easier to organize.
# 2. What is the Python kernel?
# It's an environment you can write code in. It remembers what your preferenecs are and already has packages downloaded.
# 3. What is one thing that can go wrong if you use the wrong kernel?
# When try and import a package can't be found.
# 4. What is one VS Code notebook feature you expect to use this semester?
# Run all the feature to run all cells.
